# %%
import Momentum_Backtesting_class as Mom

# %%
mombt = Mom.MomVectorBacktester('FCX','2014-01-01','2024-01-01',10000,0.0)
mombt.run_strategy(momentum=3)
mombt.plot_results()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
mombt = Mom.MomVectorBacktester('FCX','2014-01-01','2024-01-01',10000,0.001)
mombt.run_strategy(momentum=3)
mombt.plot_results()
# Out:
# [*********************100%***********************]  1 of 1 completed
