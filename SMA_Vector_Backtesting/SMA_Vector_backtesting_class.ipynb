# %%
from SMA_Backtesting import SMAVectorBacktester

# %%
smabt = SMAVectorBacktester('fcx',40,200,'2016-01-01','2024-04-01')
smabt.run_strategy()
smabt.optimize_parameters((10,40,2),(30,60,2))
# Out:
# [*********************100%***********************]  1 of 1 completed
# (array([32., 40.]), 8.56)

# %%
smabt.plot_results()
